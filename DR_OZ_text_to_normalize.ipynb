# %%
with open('/content/D1-DR.ÖZ.txt') as f:
    contents = f.read()
    print(contents)
# Out:
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ...

# %%
re_cont = contents.replace("]\n[]\n[]\n[]\n[]\n[]\n[]\n[]\n[]\n[]\n[]\n[]\n[]\n[]\n[]\n[", ',')

# %%
re_cont_v1 = re_cont.replace("]\n[]\n[]\n[]\n[]\n[]\n[]\n[]\n[]\n[]\n[]\n[]\n[]\n[]\n[]\n[", ",")

# %%
re_cont_v1
# Out:
# "[]\n[]\n[]\n[]\n[]\n[]\n[]\n[]\n[]\n[]\n[]\n[]\n[]\n[]\n[{'faceRectangle': {'top': 439, 'left': 822, 'width': 332, 'height': 332}, 'faceLandmarks': {'pupilLeft': {'x': 927.6, 'y': 519.7}, 'pupilRight': {'x': 1070.3, 'y': 535.5}, 'noseTip': {'x': 991.5, 'y': 618.1}, 'mouthLeft': {'x': 913.0, 'y': 677.3}, 'mouthRight': {'x': 1036.2, 'y': 692.4}, 'eyebrowLeftOuter': {'x': 880.8, 'y': 479.6}, 'eyebrowLeftInner': {'x': 976.4, 'y': 487.4}, 'eyeLeftOuter': {'x': 906.0, 'y': 520.5}, 'eyeLeftTop': {'x': 929.9, 'y': 513.9}, 'eyeLeftBottom': {'x': 927.4, 'y': 530.8}, 'eyeLeftInner': {'x': 950.5, 'y': 526.3}, 'eyebrowRightInner': {'x': 1040.4, 'y': 493.5}, 'eyebrowRightOuter': {'x': 1131.7, 'y': 500.6}, 'eyeRightInner': {'x': 1050.4, 'y': 540.1}, 'eyeRightTop': {'x': 1074.6, 'y': 527.7}, 'eyeRightBottom': {'x': 1074.7, 'y': 545.5}, 'eyeRightOuter': {'x': 1098.6, 'y': 538.9}, 'noseRootLeft': {'x': 983.0, 'y': 536.3}, 'noseRootRight': {'x': 1020.5, 'y': 541.5}, 'noseLeftAlarTop': {'x': 964.1, 'y'
# ...

# %%
re_cont_v2 = re_cont_v1.replace("[]\n[]\n[]\n[]\n[]\n[]\n[]\n[]\n[]\n[]\n[]\n[]\n[]\n[]\n[", "[")

# %%
re_cont_v3 = re_cont_v2.replace("]\n[]\n[]\n[]\n[]\n[]\n[]\n[]\n[]\n[]\n[]\n[]\n[]\n", "]")

# %%
re_cont_v4 = re_cont_v3.replace("'", '"')

# %%
re_cont_v4
# Out:
# '[{"faceRectangle": {"top": 439, "left": 822, "width": 332, "height": 332}, "faceLandmarks": {"pupilLeft": {"x": 927.6, "y": 519.7}, "pupilRight": {"x": 1070.3, "y": 535.5}, "noseTip": {"x": 991.5, "y": 618.1}, "mouthLeft": {"x": 913.0, "y": 677.3}, "mouthRight": {"x": 1036.2, "y": 692.4}, "eyebrowLeftOuter": {"x": 880.8, "y": 479.6}, "eyebrowLeftInner": {"x": 976.4, "y": 487.4}, "eyeLeftOuter": {"x": 906.0, "y": 520.5}, "eyeLeftTop": {"x": 929.9, "y": 513.9}, "eyeLeftBottom": {"x": 927.4, "y": 530.8}, "eyeLeftInner": {"x": 950.5, "y": 526.3}, "eyebrowRightInner": {"x": 1040.4, "y": 493.5}, "eyebrowRightOuter": {"x": 1131.7, "y": 500.6}, "eyeRightInner": {"x": 1050.4, "y": 540.1}, "eyeRightTop": {"x": 1074.6, "y": 527.7}, "eyeRightBottom": {"x": 1074.7, "y": 545.5}, "eyeRightOuter": {"x": 1098.6, "y": 538.9}, "noseRootLeft": {"x": 983.0, "y": 536.3}, "noseRootRight": {"x": 1020.5, "y": 541.5}, "noseLeftAlarTop": {"x": 964.1, "y": 590.0}, "noseRightAlarTop": {"x": 1023.7, "y": 596.3},
# ...

# %%
text_file = open("D1-DR.ÖZ-re.txt", "w")
text_file.write(re_cont_v4)
# Out:
# 268828

# %%
import os

# %%
pre, ext = os.path.splitext("D1-DR.ÖZ-re.txt")
os.rename("D1-DR.ÖZ-re.txt", "D1-DR.ÖZ-re" + ".json")

# %%
import json 
file = open("/content/D1-DR.ÖZ-re.json")
jsondata = json.load(file)

# %%
from pandas.io.json import json_normalize
normalizedjson = json_normalize(jsondata)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead

# %%
normalizedjson
# Out:
#      faceRectangle.top  ...  faceAttributes.emotion.surprise
# 0                  439  ...                              0.0
# 1                  441  ...                              0.0
# 2                  449  ...                              0.0
# 3                  439  ...                              0.0
# 4                  452  ...                              0.0
# ..                 ...  ...                              ...
# 183                473  ...                              0.0
# 184                464  ...                              0.0
# 185                473  ...                              0.0
# 186                473  ...                              0.0
# 187                471  ...                              0.0
#
# [188 rows x 66 columns]
