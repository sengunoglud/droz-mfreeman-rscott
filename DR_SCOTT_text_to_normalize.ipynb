# %%
with open('sample_data.txt') as f:
    contents = f.read()
    print(contents)
# Out:
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ...

# %%
rep = contents.replace("\n[]",'')
rep = rep.replace("\n", '')
rep = rep_re.replace("[]", '')

# %%
rep
# Out:
# "[{'faceRectangle': {'top': 497, 'left': 956, 'width': 211, 'height': 211}, 'faceLandmarks': {'pupilLeft': {'x': 1016.5, 'y': 550.7}, 'pupilRight': {'x': 1109.2, 'y': 554.3}, 'noseTip': {'x': 1056.1, 'y': 614.2}, 'mouthLeft': {'x': 1021.7, 'y': 651.8}, 'mouthRight': {'x': 1104.5, 'y': 651.7}, 'eyebrowLeftOuter': {'x': 984.0, 'y': 531.4}, 'eyebrowLeftInner': {'x': 1047.9, 'y': 530.7}, 'eyeLeftOuter': {'x': 1002.4, 'y': 554.0}, 'eyeLeftTop': {'x': 1015.0, 'y': 545.8}, 'eyeLeftBottom': {'x': 1014.5, 'y': 561.0}, 'eyeLeftInner': {'x': 1029.4, 'y': 557.6}, 'eyebrowRightInner': {'x': 1081.5, 'y': 531.2}, 'eyebrowRightOuter': {'x': 1139.8, 'y': 537.1}, 'eyeRightInner': {'x': 1092.7, 'y': 559.0}, 'eyeRightTop': {'x': 1107.0, 'y': 548.7}, 'eyeRightBottom': {'x': 1107.8, 'y': 562.7}, 'eyeRightOuter': {'x': 1121.9, 'y': 556.4}, 'noseRootLeft': {'x': 1049.7, 'y': 559.8}, 'noseRootRight': {'x': 1074.9, 'y': 560.4}, 'noseLeftAlarTop': {'x': 1040.9, 'y': 597.7}, 'noseRightAlarTop': {'x': 1082.2, 'y
# ...

# %%
text_file = open("first_draft.txt", "w")
text_file.write(rep)
# Out:
# 172128

# %%
import json 
file = open('validdata.json')
jsondata = json.load(file)

# %%
from pandas.io.json import json_normalize
normalizedjson = json_normalize(jsondata)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead

# %%
normalizedjson.to_csv("final_draft.csv")

# %%
normalizedjson
# Out:
#      faceRectangle.top  ...  faceAttributes.emotion.surprise
# 0                  497  ...                              0.0
# 1                  502  ...                              0.0
# 2                  502  ...                              0.0
# 3                  503  ...                              0.0
# 4                  503  ...                              0.0
# ..                 ...  ...                              ...
# 114                509  ...                              0.0
# 115                504  ...                              0.0
# 116                507  ...                              0.0
# 117                503  ...                              0.0
# 118                508  ...                              0.0
#
# [119 rows x 66 columns]
